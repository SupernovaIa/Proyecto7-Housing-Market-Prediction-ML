# %%
# Data processing
# -----------------------------------------------------------------------
import pandas as pd
import numpy as np

# Path configuration for custom module imports  
# -----------------------------------------------------------------------
import sys  
sys.path.append('../')  # Adds the parent directory to the path for custom module imports  

# Ignore warnings  
# -----------------------------------------------------------------------
import warnings  
warnings.filterwarnings("ignore") 

# Custom functions and classes
# -----------------------------------------------------------------------
from src.support_regression import RegressionModels

# %%
df = pd.read_csv('../data/output/api_rent_madrid_preprocessed.csv', index_col=0).reset_index(drop=True)
df.head()
# Out:
#    price      size  exterior     rooms  bathrooms  distance  municipality  \
# 0  550.0  8.442463     False  4.410093          3  1.048670    657.095509
# 1  750.0 -0.221149      True -0.712507          1 -0.896578    705.594108
# 2  750.0  0.057424      True  0.312013          1 -0.360972    685.520603
# 3  400.0 -0.026148      True  0.312013          2  1.926351    637.579238
# 4  450.0  0.586712     False  0.312013          1  1.464429    644.084662
#
#      province     hasLift  numPhotos  propertyType_chalet  \
# 0  579.687729  661.431099   1.152172                  1.0
# 1  693.233618  677.631111  -1.021827                  0.0
# 2  693.233618  670.210811  -0.090113                  0.0
# 3  693.233618  670.210811   0.634554                  0.0
# 4  579.687729  677.631111   0.013411                  0.0
#
#    propertyType_countryHouse  propertyType_duplex  propertyType_flat  \
# 0                        0.0                  0.0                0.0
# ...

# %%
model1 = RegressionModels(df, 'price')
model1.model_fit("linear")
model1.get_results()
model1.get_metrics("linear").round(2)
# Out:
#          R2    MAE   RMSE
# train  0.64  40.30  51.97
# test   0.25  45.44  63.45

# %%
model1.plot_actual_vs_prediction('linear')

# %%
model1.plot_residuals("linear")

# %% [markdown]
# ---

# %% [markdown]
# Decision tree

# %%
params_tree = {
    'max_depth': [3, 4, 5, 7],
    'min_samples_split': range(12, 20),
    'min_samples_leaf': range(3, 6),
    'max_leaf_nodes': range(20, 70, 10)
}

# %%
res = model1.model_fit("tree", params_tree)
model1.get_results()
model1.get_metrics("tree").round(2)
# Out:
#          R2    MAE   RMSE
# train  0.78  30.19  40.17
# test   0.59  36.09  46.67

# %%
par = model1.best_model['tree'].get_params()
print(par['max_depth'], par['min_samples_split'], par['min_samples_leaf'], par['max_leaf_nodes'])
# Out:
# 7 18 4 30

# %%
print(f"Profundidad del árbol: {model1.best_model['tree'].get_depth()}")
print(f"Número de nodos terminales: {model1.best_model['tree'].get_n_leaves()}")
# Out:
# Profundidad del árbol: 7
# Número de nodos terminales: 23

# %%
model1.plot_residuals("tree")

# %%
model1.predictors_importance('tree')
# Out:
#                     Predictor  Importance
# 5                municipality    0.812742
# 0                        size    0.132256
# 4                    distance    0.036151
# 2                       rooms    0.011117
# 8                   numPhotos    0.006250
# 15                      floor    0.001484
# 1                    exterior    0.000000
# 3                   bathrooms    0.000000
# 6                    province    0.000000
# 7                     hasLift    0.000000
# 9         propertyType_chalet    0.000000
# 10  propertyType_countryHouse    0.000000
# 11        propertyType_duplex    0.000000
# 12          propertyType_flat    0.000000
# 13     propertyType_penthouse    0.000000
# 14        propertyType_studio    0.000000

# %%
params_tree = {
    'max_depth': [3, 4, 5, 7],
    'min_samples_split': range(12, 20),
    'min_samples_leaf': range(3, 6),
    'max_leaf_nodes': range(20, 70, 10)
}

res = model1.model_fit("tree", params_tree)
model1.get_results()
model1.get_metrics("tree").round(2)
# Out:
#          R2    MAE   RMSE
# train  0.78  30.19  40.17
# test   0.59  36.09  46.67

# %% [markdown]
# ---

# %%
params_rf = {
    'max_depth': [3, 4, 5, 6],
    'min_samples_split': range(5, 15),
    'min_samples_leaf': range(1, 10),
    'max_leaf_nodes': range(5, 51, 5)
}

res = model1.model_fit("random_forest", params_rf)
model1.get_results()
model1.get_metrics("random_forest").round(2)
# Out:
#          R2    MAE   RMSE
# train  0.83  27.31  35.96
# test   0.59  36.27  46.82

# %%
model1.predictors_importance('random_forest')
# Out:
#                     Predictor  Importance
# 5                municipality    0.782448
# 0                        size    0.088932
# 4                    distance    0.037304
# 2                       rooms    0.022927
# 8                   numPhotos    0.020887
# 15                      floor    0.017347
# 6                    province    0.008422
# 7                     hasLift    0.005681
# 1                    exterior    0.004807
# 9         propertyType_chalet    0.004635
# 3                   bathrooms    0.004370
# 13     propertyType_penthouse    0.001457
# 12          propertyType_flat    0.000549
# 14        propertyType_studio    0.000233
# 10  propertyType_countryHouse    0.000000
# 11        propertyType_duplex    0.000000

# %% [markdown]
# ---

# %%
params_gb = {
    'n_estimators': [50, 100, 150],
    'learning_rate': [0.01, 0.1, 0.2],
    'max_depth': [3, 4, 5],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

model1.model_fit("gradient_boosting", params_gb)
model1.get_results()
model1.get_metrics("gradient_boosting").round(2)
# Out:
#          R2    MAE   RMSE
# train  0.84  26.68  34.77
# test   0.58  35.36  47.52

# %%
model1.plot_actual_vs_prediction('gradient_boosting')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[83], line 1
# ----> 1 model1.plot_actual_vs_prediction('gradient_boosting')
#
# Cell In[68], line 148, in RegressionModels.plot_actual_vs_prediction(self, model)
#     145 y_test_pred = self.best_model[model].predict(self.X_test)
#     146 y_test = self.y_test
# --> 148 metrics = self.get_metrics(self, model)
#     150 r2_train = metrics['R2']['train']
#     151 rmse_train = metrics['RMSE']['train']
#
# TypeError: RegressionModels.get_metrics() takes 2 positional arguments but 3 were given
